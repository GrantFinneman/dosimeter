# %% [markdown]
# # No_convolutions AI
#
# This neural net will not have any 2D or 3D convolutions, it will only have sequential Dense layers

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import metrics, losses
from tensorflow.keras.layers import *
import numpy as np
import random
import matplotlib.pyplot as plt
from datetime import date
import sys
sys.path.append('/home/gmf/Projects/dosimeter/')
from my_classes import *

# %%
energy_dict = load_data_ohio()

# %%
energies = [energy for energy in energy_dict.values()]

# %%
energies
# Out:
# [array([ 38483.92678,  39382.46837,  36595.07939,  38020.8795 ,
#          40114.97684,  39227.92084,  37465.65117,  35604.47592,
#          42128.43818,  44554.72048,  39955.84713,  43501.75045,
#          46611.26704,  38664.30159,  37933.22125,  38154.59856,
#          52850.0574 ,  47445.7162 ,  55851.44422,  45917.08286,
#          55757.47791,  58439.41509,  56898.10613,  43116.24467,
#         126116.68652, 118227.86251, 189570.77148, 122588.33874,
#         176140.25701, 162216.52386, 131985.56281,  84691.65654,
#         208366.40992, 285327.77665, 294911.20737, 483994.11657,
#         345908.89731, 244549.97751, 361085.97108, 184160.53878,
#          54215.51431,  61556.13238,  57231.12404,  71271.31838,
#          74523.89695,  68536.35784,  60613.31542,  70698.29657,
#          42413.31255,  41870.10531,  42411.17023,  40777.68026,
#          42913.01805,  43572.38884,  48624.31182,  43052.56899,
#          38391.38869,  39127.58697,  38908.11406,  39157.3419 ,
# ...
